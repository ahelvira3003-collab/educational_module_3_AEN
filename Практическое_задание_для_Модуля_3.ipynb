# %% [markdown]
# <a href="https://colab.research.google.com/github/ahelvira3003-collab/educational_module_3_AEN/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%BB%D1%8F_%D0%9C%D0%BE%D0%B4%D1%83%D0%BB%D1%8F_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Это мое первое текстовое поле.

# %%
print('Это мое первое текстовое поле.')
# Out:
# Это мое первое текстовое поле.
